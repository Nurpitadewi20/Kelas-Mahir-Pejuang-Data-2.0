# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurpitadewi20/Kelas-Mahir-Pejuang-Data-2.0/blob/main/TensorFlow_Bag7_Per2_Nurpita_Dewi_1900015010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://lh3.googleusercontent.com/-1Xzmk_Q6pUY/YMOG4DwnGbI/AAAAAAAABAQ/QwEVa4dSGnsDEqUA6dYII_iBWzu94nC4ACLcBGAsYHQ/s16000/header_NNTF.png)

# %% [markdown]
# # Pendahuluan

# %% [markdown]
# Ini adalah notebook terpadu untuk Deep Learning menggunakan library TensorFlow untuk Kelas Mahir Program Pejuang Data 2.0 Tahun 2021. Silahkan teman-teman pelajari dengan seksama notebook ini dengan urut. Notebook ini disusun secara berurutan mulai dari dasar hingga temen-temen bisa membuat tugas akhir seperti yang sudah dibagikan minggu lalu.
# Notebook ini bersifat interaktif sehingga manfaat betul fitur ini untuk mendapatkan pemahaman yang menyeluruh.
#
# Berikut adalah bagian-bagian dari notebook ini beserta tujuan masing-masing bagiannya:
# 1. **Pengenalan TensorFlow** : Pada bagian ini temen-temen akan mempelajari dasar-dasar Model Neural Network dan penulisan sintaxs TensorFlow. Beberapa hal yang harus temen-temen pahami pada bab ini adalah: proses pembuatan model yaitu *membangun arsitektur model, compile model, menyiapkan data, training data, dan prediksi data* Sebagai tambahan pemahaman secara menyeluruh pastikan bentuk input, dan output data, serta parameter-parameter pada struktur model
# 2. **

# %% [markdown]
# # Pengenalan Model Neural Network

# %% [markdown]
# Jaringan Syaraf Tiruan adalah suatu metode yang prinsip kerjanya diadaptasi dari model matematika pada manusia atau syaraf biologi. Jaringan syaraf dikarakteristikkan oleh;
#
# 1. pola koneksi diantara neuron (disebut arsitektur),
# 2. menentukan bobot dari koneksi (disebut training atau learning),
# 3. fungsi aktifasi.
#
# https://jurnal.stmikasia.ac.id/index.php/jitika/article/download/213/162/#:~:text=Jaringan%20Syaraf%20Tiruan%20adalah%20suatu,dan%20(3)%20fungsi%20aktifasi.
#
# ## Model Perceptron
#
# <table>
#   <tr><td>
#     <img src="https://lh3.googleusercontent.com/-X7d72Q3hEkg/YMOG3zecuCI/AAAAAAAABAM/NFIHbB7VtB4P72fTqcZkEmNlAfoPMdjAQCLcBGAsYHQ/s16000/perceptron_0.png">
#   </td></tr>
# <table>
#
#
# ### Single Perceptron Model
#
# <table>
#   <tr><td>
#     <img src="https://lh3.googleusercontent.com/-qwYstl8AJy8/YMOG3fsJGRI/AAAAAAAABAE/QRO5VIJ764YSCLY3Gege_UqUTPxTVbjGACLcBGAsYHQ/s16000/perceptron_1.png">
#   </td></tr>
# <table>
#
#
# ## Multiple Perceptron Model
#
# <table>
#   <tr><td>
#     <img src="https://lh3.googleusercontent.com/-TRqlhs2aszg/YMOG3sBHduI/AAAAAAAABAI/6oqQF36M6YAgrJvZ49sM7YGluTcxAsOQACLcBGAsYHQ/s16000/perceptron_3.png">
#   </td></tr>
# <table>

# %% [markdown]
# # Pengenalan TensorFlow

# %% [markdown]
# ## Model Neural Networks Dasar

# %% [markdown]
# Tensorflow adalah sebuah library pada python untuk Deep learning. Pada bagian temen-temen akan fokus pada syntaks bagaimana melakukan pemodelan Neural Network menggunakan library TensorFlow python. Pada bagian ini kita akan mulai pada kasus yang paling sederhana yaitu adalah Tabel Logika "And" sebagai berikut:
#
# ```
# x1  x2  y
# 1   1   1
# 1   0   0
# 0   1   0
# 0   0   0
# ```
#
# Perhatikan bahwa `x1` , dan `x2` adalah input dan `y` adalah output yang diinginkan. Maka **ukuran input adalah dua kolom dan 4 baris sedangkan input adalah sebuah nilai antara 0 dan 1.**

# %%
# Import Library
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
# Menampilkan Versi TensorFlow
tf.__version__
# Out:
# '2.5.0'

# %%
# Menyusun model
model = keras.Sequential([                                # Membentuk model sequential                                           #Layer input untuk Deep Learning Neural Network
    tf.keras.layers.Dense(units=1, 
                          input_shape=[2], 
                          activation='relu'),             # Menambah layer pada model NN
])

# Compile model
model.compile(loss='mean_squared_error',                  # Menentukan fungsi loss
              optimizer='sgd')                            # Menentukan fungsi optimizer

model.summary()                                           # Menampilkan summary model
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Berdasarkan model summary di atas maka kita sedang membuat model NN dengan satu titik layer. Kemudian hasil parameternya adalah tiga. Itu berarti terdapat tiga parameter, Apa aja? Yups betul, `w1`, `w2` karena inputnya adalah `x1` dan `x2`, serta `b` yaitu bias. Berikut adalah visualisasi NN modelnya:
#
# <table>
#   <tr><td>
#     <img src="https://lh3.googleusercontent.com/-5WekbjocJRw/YMOG3VGl9ZI/AAAAAAAABAA/yeYPFdlkxQUOQjKHBfEzd7xN7RGFOdtVACLcBGAsYHQ/s16000/perceptron_4.png">
#   </td></tr>
# <table>

# %%
# Mendefinisikan Data Input(X) & Output(Y)
x = np.array([[1,1], [1,0], [0,1], [0,0]], dtype="int")
y = np.array([[1], [0], [0], [0]], dtype="int")

# %%
# Menampilkan data X
x
# Out:
# array([[1, 1],
#        [1, 0],
#        [0, 1],
#        [0, 0]])

# %%
# Menampilkan data y
y
# Out:
# array([[1],
#        [0],
#        [0],
#        [0]])

# %%
# Melatih model(fitting/training)
history = model.fit(x, y, epochs=2000, verbose=2)
# Out:
# Epoch 1/2000
# 1/1 - 1s - loss: 0.2500
# Epoch 2/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 3/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 4/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 5/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 6/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 7/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 8/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 9/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 10/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 11/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 12/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 13/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 14/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 15/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 16/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 17/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 18/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 19/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 20/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 21/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 22/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 23/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 24/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 25/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 26/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 27/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 28/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 29/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 30/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 31/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 32/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 33/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 34/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 35/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 36/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 37/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 38/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 39/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 40/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 41/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 42/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 43/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 44/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 45/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 46/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 47/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 48/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 49/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 50/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 51/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 52/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 53/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 54/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 55/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 56/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 57/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 58/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 59/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 60/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 61/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 62/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 63/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 64/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 65/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 66/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 67/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 68/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 69/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 70/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 71/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 72/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 73/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 74/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 75/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 76/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 77/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 78/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 79/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 80/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 81/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 82/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 83/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 84/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 85/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 86/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 87/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 88/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 89/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 90/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 91/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 92/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 93/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 94/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 95/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 96/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 97/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 98/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 99/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 100/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 101/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 102/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 103/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 104/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 105/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 106/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 107/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 108/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 109/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 110/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 111/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 112/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 113/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 114/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 115/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 116/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 117/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 118/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 119/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 120/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 121/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 122/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 123/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 124/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 125/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 126/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 127/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 128/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 129/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 130/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 131/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 132/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 133/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 134/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 135/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 136/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 137/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 138/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 139/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 140/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 141/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 142/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 143/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 144/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 145/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 146/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 147/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 148/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 149/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 150/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 151/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 152/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 153/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 154/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 155/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 156/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 157/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 158/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 159/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 160/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 161/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 162/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 163/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 164/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 165/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 166/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 167/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 168/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 169/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 170/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 171/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 172/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 173/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 174/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 175/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 176/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 177/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 178/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 179/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 180/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 181/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 182/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 183/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 184/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 185/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 186/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 187/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 188/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 189/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 190/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 191/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 192/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 193/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 194/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 195/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 196/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 197/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 198/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 199/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 200/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 201/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 202/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 203/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 204/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 205/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 206/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 207/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 208/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 209/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 210/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 211/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 212/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 213/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 214/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 215/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 216/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 217/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 218/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 219/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 220/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 221/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 222/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 223/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 224/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 225/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 226/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 227/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 228/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 229/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 230/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 231/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 232/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 233/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 234/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 235/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 236/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 237/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 238/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 239/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 240/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 241/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 242/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 243/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 244/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 245/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 246/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 247/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 248/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 249/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 250/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 251/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 252/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 253/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 254/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 255/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 256/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 257/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 258/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 259/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 260/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 261/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 262/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 263/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 264/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 265/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 266/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 267/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 268/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 269/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 270/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 271/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 272/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 273/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 274/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 275/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 276/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 277/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 278/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 279/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 280/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 281/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 282/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 283/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 284/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 285/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 286/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 287/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 288/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 289/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 290/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 291/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 292/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 293/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 294/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 295/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 296/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 297/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 298/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 299/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 300/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 301/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 302/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 303/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 304/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 305/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 306/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 307/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 308/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 309/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 310/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 311/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 312/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 313/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 314/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 315/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 316/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 317/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 318/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 319/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 320/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 321/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 322/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 323/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 324/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 325/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 326/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 327/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 328/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 329/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 330/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 331/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 332/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 333/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 334/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 335/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 336/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 337/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 338/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 339/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 340/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 341/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 342/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 343/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 344/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 345/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 346/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 347/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 348/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 349/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 350/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 351/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 352/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 353/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 354/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 355/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 356/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 357/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 358/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 359/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 360/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 361/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 362/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 363/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 364/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 365/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 366/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 367/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 368/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 369/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 370/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 371/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 372/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 373/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 374/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 375/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 376/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 377/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 378/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 379/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 380/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 381/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 382/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 383/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 384/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 385/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 386/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 387/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 388/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 389/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 390/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 391/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 392/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 393/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 394/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 395/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 396/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 397/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 398/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 399/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 400/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 401/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 402/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 403/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 404/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 405/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 406/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 407/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 408/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 409/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 410/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 411/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 412/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 413/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 414/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 415/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 416/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 417/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 418/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 419/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 420/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 421/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 422/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 423/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 424/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 425/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 426/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 427/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 428/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 429/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 430/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 431/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 432/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 433/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 434/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 435/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 436/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 437/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 438/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 439/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 440/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 441/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 442/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 443/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 444/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 445/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 446/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 447/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 448/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 449/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 450/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 451/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 452/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 453/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 454/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 455/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 456/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 457/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 458/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 459/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 460/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 461/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 462/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 463/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 464/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 465/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 466/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 467/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 468/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 469/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 470/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 471/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 472/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 473/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 474/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 475/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 476/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 477/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 478/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 479/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 480/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 481/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 482/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 483/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 484/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 485/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 486/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 487/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 488/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 489/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 490/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 491/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 492/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 493/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 494/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 495/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 496/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 497/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 498/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 499/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 500/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 501/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 502/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 503/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 504/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 505/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 506/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 507/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 508/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 509/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 510/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 511/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 512/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 513/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 514/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 515/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 516/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 517/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 518/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 519/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 520/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 521/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 522/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 523/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 524/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 525/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 526/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 527/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 528/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 529/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 530/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 531/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 532/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 533/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 534/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 535/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 536/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 537/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 538/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 539/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 540/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 541/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 542/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 543/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 544/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 545/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 546/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 547/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 548/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 549/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 550/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 551/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 552/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 553/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 554/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 555/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 556/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 557/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 558/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 559/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 560/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 561/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 562/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 563/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 564/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 565/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 566/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 567/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 568/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 569/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 570/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 571/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 572/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 573/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 574/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 575/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 576/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 577/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 578/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 579/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 580/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 581/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 582/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 583/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 584/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 585/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 586/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 587/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 588/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 589/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 590/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 591/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 592/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 593/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 594/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 595/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 596/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 597/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 598/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 599/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 600/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 601/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 602/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 603/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 604/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 605/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 606/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 607/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 608/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 609/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 610/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 611/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 612/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 613/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 614/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 615/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 616/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 617/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 618/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 619/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 620/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 621/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 622/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 623/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 624/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 625/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 626/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 627/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 628/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 629/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 630/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 631/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 632/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 633/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 634/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 635/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 636/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 637/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 638/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 639/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 640/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 641/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 642/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 643/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 644/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 645/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 646/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 647/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 648/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 649/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 650/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 651/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 652/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 653/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 654/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 655/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 656/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 657/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 658/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 659/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 660/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 661/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 662/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 663/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 664/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 665/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 666/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 667/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 668/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 669/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 670/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 671/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 672/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 673/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 674/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 675/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 676/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 677/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 678/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 679/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 680/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 681/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 682/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 683/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 684/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 685/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 686/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 687/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 688/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 689/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 690/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 691/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 692/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 693/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 694/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 695/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 696/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 697/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 698/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 699/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 700/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 701/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 702/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 703/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 704/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 705/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 706/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 707/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 708/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 709/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 710/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 711/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 712/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 713/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 714/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 715/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 716/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 717/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 718/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 719/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 720/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 721/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 722/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 723/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 724/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 725/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 726/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 727/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 728/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 729/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 730/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 731/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 732/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 733/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 734/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 735/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 736/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 737/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 738/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 739/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 740/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 741/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 742/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 743/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 744/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 745/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 746/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 747/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 748/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 749/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 750/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 751/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 752/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 753/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 754/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 755/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 756/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 757/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 758/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 759/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 760/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 761/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 762/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 763/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 764/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 765/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 766/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 767/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 768/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 769/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 770/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 771/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 772/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 773/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 774/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 775/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 776/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 777/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 778/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 779/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 780/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 781/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 782/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 783/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 784/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 785/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 786/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 787/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 788/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 789/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 790/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 791/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 792/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 793/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 794/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 795/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 796/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 797/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 798/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 799/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 800/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 801/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 802/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 803/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 804/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 805/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 806/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 807/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 808/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 809/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 810/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 811/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 812/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 813/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 814/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 815/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 816/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 817/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 818/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 819/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 820/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 821/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 822/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 823/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 824/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 825/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 826/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 827/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 828/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 829/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 830/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 831/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 832/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 833/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 834/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 835/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 836/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 837/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 838/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 839/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 840/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 841/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 842/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 843/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 844/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 845/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 846/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 847/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 848/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 849/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 850/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 851/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 852/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 853/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 854/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 855/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 856/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 857/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 858/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 859/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 860/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 861/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 862/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 863/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 864/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 865/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 866/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 867/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 868/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 869/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 870/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 871/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 872/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 873/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 874/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 875/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 876/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 877/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 878/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 879/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 880/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 881/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 882/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 883/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 884/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 885/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 886/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 887/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 888/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 889/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 890/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 891/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 892/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 893/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 894/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 895/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 896/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 897/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 898/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 899/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 900/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 901/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 902/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 903/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 904/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 905/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 906/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 907/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 908/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 909/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 910/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 911/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 912/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 913/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 914/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 915/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 916/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 917/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 918/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 919/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 920/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 921/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 922/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 923/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 924/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 925/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 926/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 927/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 928/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 929/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 930/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 931/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 932/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 933/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 934/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 935/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 936/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 937/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 938/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 939/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 940/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 941/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 942/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 943/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 944/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 945/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 946/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 947/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 948/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 949/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 950/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 951/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 952/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 953/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 954/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 955/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 956/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 957/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 958/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 959/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 960/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 961/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 962/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 963/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 964/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 965/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 966/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 967/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 968/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 969/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 970/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 971/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 972/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 973/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 974/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 975/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 976/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 977/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 978/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 979/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 980/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 981/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 982/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 983/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 984/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 985/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 986/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 987/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 988/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 989/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 990/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 991/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 992/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 993/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 994/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 995/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 996/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 997/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 998/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 999/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1000/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1001/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1002/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1003/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1004/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1005/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1006/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1007/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1008/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1009/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1010/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1011/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1012/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1013/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1014/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1015/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1016/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1017/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1018/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1019/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1020/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1021/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1022/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1023/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1024/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1025/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1026/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1027/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1028/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1029/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1030/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1031/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1032/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1033/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1034/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1035/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1036/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1037/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1038/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1039/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1040/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1041/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1042/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1043/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1044/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1045/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1046/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1047/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1048/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1049/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1050/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1051/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1052/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1053/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1054/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1055/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1056/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1057/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1058/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1059/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1060/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1061/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1062/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1063/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1064/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1065/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1066/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1067/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1068/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1069/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1070/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1071/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1072/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1073/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1074/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1075/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1076/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1077/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1078/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1079/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1080/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1081/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1082/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1083/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1084/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1085/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1086/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1087/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1088/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1089/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1090/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1091/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1092/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1093/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1094/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1095/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1096/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1097/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1098/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1099/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1100/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1101/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1102/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1103/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1104/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1105/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1106/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1107/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1108/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1109/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1110/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1111/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1112/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1113/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1114/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1115/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1116/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1117/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1118/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1119/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1120/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1121/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1122/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1123/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1124/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1125/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1126/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1127/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1128/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1129/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1130/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1131/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1132/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1133/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1134/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1135/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1136/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1137/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1138/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1139/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1140/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1141/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1142/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1143/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1144/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1145/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1146/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1147/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1148/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1149/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1150/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1151/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1152/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1153/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1154/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1155/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1156/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1157/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1158/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1159/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1160/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1161/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1162/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1163/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1164/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1165/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1166/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1167/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1168/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1169/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1170/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1171/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1172/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1173/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1174/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1175/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1176/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1177/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1178/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1179/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1180/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1181/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1182/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1183/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1184/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1185/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1186/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1187/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1188/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1189/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1190/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1191/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1192/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1193/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1194/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1195/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1196/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1197/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1198/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1199/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1200/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1201/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1202/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1203/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1204/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1205/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1206/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1207/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1208/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1209/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1210/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1211/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1212/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1213/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1214/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1215/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1216/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1217/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1218/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1219/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1220/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1221/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1222/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1223/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1224/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1225/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1226/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1227/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1228/2000
# ...
# Epoch 1601/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1602/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1603/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1604/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1605/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1606/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1607/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1608/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1609/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1610/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1611/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1612/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1613/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1614/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1615/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1616/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1617/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1618/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1619/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1620/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1621/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1622/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1623/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1624/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1625/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1626/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1627/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1628/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1629/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1630/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1631/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1632/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1633/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1634/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1635/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1636/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1637/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1638/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1639/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1640/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1641/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1642/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1643/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1644/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1645/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1646/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1647/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1648/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1649/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1650/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1651/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1652/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1653/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1654/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1655/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1656/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1657/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1658/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1659/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1660/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1661/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1662/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1663/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1664/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1665/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1666/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1667/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1668/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1669/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1670/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1671/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1672/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1673/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1674/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1675/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1676/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1677/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1678/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1679/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1680/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1681/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1682/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1683/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1684/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1685/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1686/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1687/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1688/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1689/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1690/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1691/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1692/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1693/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1694/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1695/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1696/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1697/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1698/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1699/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1700/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1701/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1702/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1703/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1704/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1705/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1706/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1707/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1708/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1709/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1710/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1711/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1712/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1713/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1714/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1715/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1716/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1717/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1718/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1719/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1720/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1721/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1722/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1723/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1724/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1725/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1726/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1727/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1728/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1729/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1730/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1731/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1732/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1733/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1734/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1735/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1736/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1737/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1738/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1739/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1740/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1741/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1742/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1743/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1744/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1745/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1746/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1747/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1748/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1749/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1750/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1751/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1752/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1753/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1754/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1755/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1756/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1757/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1758/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1759/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1760/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1761/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1762/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1763/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1764/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1765/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1766/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1767/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1768/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1769/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1770/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1771/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1772/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1773/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1774/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1775/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1776/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1777/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1778/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1779/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1780/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1781/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1782/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1783/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1784/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1785/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1786/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1787/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1788/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1789/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1790/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1791/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1792/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1793/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1794/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1795/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1796/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1797/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1798/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1799/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1800/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1801/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1802/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1803/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1804/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1805/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1806/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1807/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1808/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1809/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1810/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1811/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1812/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1813/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1814/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1815/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1816/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1817/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1818/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1819/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1820/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1821/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1822/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1823/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1824/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1825/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1826/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1827/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1828/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1829/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1830/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1831/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1832/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1833/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1834/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1835/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1836/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1837/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1838/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1839/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1840/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1841/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1842/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1843/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1844/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1845/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1846/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1847/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1848/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1849/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1850/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1851/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1852/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1853/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1854/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1855/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1856/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1857/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1858/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1859/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1860/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1861/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1862/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1863/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1864/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1865/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1866/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1867/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1868/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1869/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1870/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1871/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1872/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1873/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1874/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1875/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1876/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1877/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1878/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1879/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1880/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1881/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1882/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1883/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1884/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1885/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1886/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1887/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1888/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1889/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1890/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1891/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1892/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1893/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1894/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1895/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1896/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1897/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1898/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1899/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1900/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1901/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1902/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1903/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1904/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1905/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1906/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1907/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1908/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1909/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1910/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1911/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1912/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1913/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1914/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1915/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1916/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1917/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1918/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1919/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1920/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1921/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1922/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1923/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1924/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1925/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1926/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1927/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1928/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1929/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1930/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1931/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1932/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1933/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1934/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1935/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1936/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1937/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1938/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1939/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1940/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1941/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1942/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1943/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1944/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1945/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1946/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1947/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1948/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1949/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1950/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1951/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1952/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1953/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1954/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1955/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1956/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1957/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1958/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1959/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1960/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1961/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1962/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1963/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1964/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1965/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1966/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1967/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1968/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1969/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1970/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1971/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1972/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1973/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1974/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1975/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1976/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1977/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1978/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1979/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1980/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1981/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1982/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1983/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1984/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1985/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1986/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1987/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1988/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1989/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1990/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1991/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1992/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1993/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1994/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1995/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1996/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1997/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1998/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 1999/2000
# 1/1 - 0s - loss: 0.2500
# Epoch 2000/2000
# 1/1 - 0s - loss: 0.2500

# %%
# Prediksi Model
model.predict(x)
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
# Membulatkan Hasil Pemodelan
model.predict(x).round()
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
# Menampilkan nilai bobot
model.get_weights()
# Out:
# [array([[-0.6372981],
#         [-1.3038568]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# ## Model Neural Network untuk Klasifikasi Gambar

# %% [markdown]
# ### Representasi Citra Digital

# %% [markdown]
# Dalam sebuah komputer, citra digital dipetakan menjadi bentuk grid dan elemen piksel berbentuk matriks 2 dimensi. Setiap piksel-piksel tersebut memiliki angka yang mempresentasikan channel warna. Angka pada setiap piksel disimpan secara berurutan oleh sebuah komputer dan sering dikurangi untuk keperluan kompresi maupun pengolahan tertentu. Sebuah citra digital dapat mewakili oleh sebuah matriks yang terdiri dari M baris N kolom, dimana perpotongan antara kolom dan baris disebut piksel.
# (**pixel = picture element**), yaitu elemen terkecil dari sebuah citra. Piksel mempunyai dua parameter, yaitu koordinat dan intensitas atau warna. Nilai yang terdapat pada koordinat $(\ x, y)$ adalah $\ f(x, y) $, yaitu besar intensitas atau warna dari piksel di titik itu. Oleh karena itu, citra dapat dituliskan kedalam sebuah matriks :

# %% [markdown]
# $$
# \begin{eqnarray}
# \ f(x,y) &=& \begin{bmatrix}
# f(0,0) & f(0,1) & \ldots & f(0,N-1)\\
# f(1,0) & f(1,1) & \ldots & f(1,N-1)\\
# \vdots & \vdots & \vdots & f(0,N-1)\\
# f(M-1,0) & f(M-1,1) & \ldots & f(M-1,N-1)
# \end{bmatrix}
# \end{eqnarray}
# $$

# %% [markdown]
# Berdasarkan rumus diatas, suatu citra $\ f(x, y) $ dapat dituliskan kedalam fungsi matematis seperti berikut ini :

# %% [markdown]
# $$
# \begin{eqnarray}
# 0  \leq  x   \leq M-1\\
# 0  \leq  y   \leq N-1\\
# 0  \leq  f(x,y)   \leq G-1\\
# \end{eqnarray}
# $$

# %% [markdown]
# Dimana :
#
# M = jumlah piksel baris pada array citra
#
# N = jumlah piksel kolom pada array citra
#
# G = nilai skala keabuan (grayscale )
#
# Besarnya nilai M, N, dan G biasanya merupakan perpengkatan dari dua seperti yang terlihat pada persamaan berikut :
#
# $\ M = 2m ; N = 2n; G =2k 	$

# %% [markdown]
# Dimana nilai m, n, dan k merupakan bilaingan positif. Interval (0, G) disebut dengan (grayscale). Besarnya nilai G tergantung pada proses digitalisasinya. Biasanya keabuan 0 (nol) menyatakan  intensitas hitam dan 1 (satu) menyatakan intensitas putih. Untuk citra 8 bit, nilai G sama dengan 28 = 256 warna (derajat keabuan).
#
# **Catatan Penting:**
#
# Interval nilai untuk nilai Grayscale adalah 0-255
#
#
# <table>
#   <tr><td>
#     <img src="https://lh3.googleusercontent.com/-udUdtxNb0GI/YMOG23D92oI/AAAAAAAAA_8/tQBvbYgjur0y-TwimgvWBIDYWWXaA1lZwCLcBGAsYHQ/s16000/CitDig.png">
#   </td></tr>
# <table>

# %% [markdown]
# ### Contoh Citra Digital: Dataset Fashion MNIST

# %% [markdown]
# Dataset Fashion MNIST yang berisi 70.000 gambar grayscale dalam 10 kategori. Setiap gambar menunjukkan jenis pakaian dengan resolusi rendah (28 kali 28 piksel), seperti yang terlihat di sini:
#
# <table>
#   <tr><td>
#     <img src="https://lh3.googleusercontent.com/IlIqpi0ufByXzQnERKwvgozJzoU6_pFSGXMn8spU1dKHwM7JbA6ofxsAAAdmUMs36P_harPw5PVRjl8=w1349-h625" alt=" number MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#   </td></tr>
# </table>
#
# Fashion MNIST dimaksudkan sebagai pengganti drop-in untuk kumpulan data MNIST klasik — sering digunakan sebagai "Halo, Dunia" (Pengenalan) dari program pembelajaran mesin untuk computer vision. Dataset MNIST berisi gambar digit tulisan tangan (0, 1, 2, dll.) Dalam format yang identik, data ini berbentuk gambar jenis-jenis pakaian.
#
# Dataset ini terdiri atas 60.000 gambar digunakan untuk melatih model dan 10.000 gambar untuk mengevaluasi seberapa akurat model untuk mengklasifikasikan gambar. Kita dapat mengakses dataset Fashion MNIST langsung dari TensorFlow. Impor dan muat data Fashion MNIST langsung dari TensorFlow sebagai berikut:

# %%
number_mnist = keras.datasets.mnist
(gambar_latih, label_latih), (gambar_uji, label_uji) = number_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Kamu telah berhasil memuat data dalam empat array Numpy yaitu:
#
# * `gambar_latih` dan `label_latih` untuk melakukan pelatihan/pebelajaran model
# * Kemudian model yang dihasilkan diuji akurasinya menggunakan data `gambar_uji` dan `label_uji`

# %% [markdown]
# Gambar ini merupakan adalah array NumPy berukuran 28x28, dengan nilai piksel mulai dari 0 hingga 255. Label adalah array  bilangan bulat, mulai dari 0 hingga 9. Ini sesuai dengan kelas pakaian yang mewakili gambar dengan rincian sebagai berikut:
#
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>1</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>2</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>3</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>4</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>5</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>6</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>7</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>8</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>9</td>
#   </tr>
# </table>

# %% [markdown]
# Setiap gambar dipetakan ke suatu label. Karena nama kelas tidak disertakan dengan kumpulan data, simpan di sini untuk digunakan nanti saat memplot gambar:

# %%
nama_kelas = ['1', '2', '3', '4', '5',
               '6', '7', '8', '9', 'Bag', 'Ankle boot']

# %% [markdown]
# Mari jelajahi format set data sebelum melatih model. Berikut ini adalah tampilan 60.000 gambar dalam himpunan pelatihan, dengan setiap gambar direpresentasikan sebagai 28 x 28 piksel:

# %%
gambar_latih.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Demikian pula, ada 60.000 label di set pelatihan:

# %%
len(label_latih)
# Out:
# 60000

# %% [markdown]
# Setiap label adalah bilangan bulat antara 0 dan 9:

# %%
label_latih
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %% [markdown]
# Kemudian terdapat 10.000 gambar dalam himpunan pengujian. Sekali lagi, setiap gambar direpresentasikan sebagai 28 x 28 piksel:

# %%
gambar_uji.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# Dan himpunan pengujian berisi 10.000 label gambar:

# %%
len(label_uji)
# Out:
# 10000

# %% [markdown]
# Mari kita melakukan visualisasi data angka MNIST sebagai berikut:

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(gambar_latih[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Untuk melakukan proses pemodelan, skalakan nilai ini ke rentang 0 hingga 1 sebelum memasukkannya ke model Neural Network. Untuk melakukannya, bagi nilai dengan 255. Penting bahwa himpunan pelatihan dan himpunan pengujian diproses sebelumnya dengan cara yang sama:

# %%
gambar_latih = gambar_latih / 255.0

gambar_uji = gambar_uji / 255.0

# %% [markdown]
# Untuk memverifikasi bahwa data dalam format yang benar dan kita siap untuk membangun dan melatih model, mari kita tampilkan 25 gambar pertama dari himpunan pelatihan dan tampilkan nama kelas di bawah setiap gambar.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(gambar_latih[i], cmap=plt.cm.binary)
    plt.xlabel(nama_kelas[label_latih[i]])
plt.show()

# %% [markdown]
# Kemudian kita akan mulai membangun model Neural Network seperti di bawah ini:

# %%
# Membangun Model 
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),                   # layer Input
    tf.keras.layers.Dense(128, activation='relu'),                   # Hiden Layer Pertama
    tf.keras.layers.Dense(10)                                        # Layer Output
])

# %% [markdown]
# Mulai sekarang, mari kita berlatih untuk membuat model NN yang selalu terdiri dari layer utama yaitu *Layer Input, Layer Hiden/Layer Model Lainnya, dan Layer Output**.
#
# Pada layer pertama digunakan jenis layer `Flatten`, ini berfungsi untuk mengubah array berukuran 28 x 28 menjadi 1 x 28*28 yaitu 1 x 784 pixel. Kita harus melakukan hal ini.
#
# Setelah piksel diratakan(Flatten), layer selanjutnya terdiri dari urutan dua lapisan Dense.
# Ini merupakan layer-layer yang sepenuhnya terhubung.
#
# Layer Dense pertama(layer kedua) merupakan Hiden layer dengan titik(node) sebanyak 128 titik.
#
# Kemudian lapisan terakhir adalah layer output. Karena data ini memiliki sepuluh label, maka kita beri parameter 10 yang akan menghasilkan array logits dengan panjang 10. Array ini adalah array dengan nilai probabilitas di masing-masing kelas. Kelas dengan nilai probabilitas tertinggi akan menjadi kelas hasil prediksi.

# %% [markdown]
# Langkah selanjutnya adalah melakukan kompilasi model. Pada langkah ini, seperti sebelumnya, kita harus mendefinisikan dua fungsi utama dan memungkinkan menentukan beberapa fungsi lainnya. Dua hal yang harus ditentukan adalah:
#
# 1. Fungsi `Loss` atau fungsi kerugian: Fungsi ini mengukur tingkat kesalah model yang dihasilkan
# 2. Fungsi `Optimizer` atau fungsi optimasi: Fungsi ini bertugas untuk melakukan optimisasi model.
# 3. Fungsi `Metrik`, ini tidak wajib. Fungsi ini berfungsi untuk menampilkan ukuran tertentu, biasanya Akurasi

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),  # Fungsi Loss
              
              optimizer='adam',                                                      # Fungsi Optimasi
              
              metrics=['accuracy'])                                                  # Metrik akurasi

# %% [markdown]
# Langkah selanjutnya adalah melakukan pelatihan model dengan metode `model.fit` sebagai berikut:

# %%
model.fit(gambar_latih,                         # Data latih
          label_latih,                          # Label latih
          epochs=10)                            # Epoch(iterasi)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2529 - accuracy: 0.9288
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1106 - accuracy: 0.9675
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0771 - accuracy: 0.9768
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0573 - accuracy: 0.9823
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0447 - accuracy: 0.9861
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0356 - accuracy: 0.9892
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0274 - accuracy: 0.9915
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0238 - accuracy: 0.9927
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0190 - accuracy: 0.9939
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9954

# %% [markdown]
# Saat model pelatihan, metrik kerugian dan akurasi ditampilkan. Model ini mencapai akurasi sekitar 0,9956 (atau 99%) pada data pelatihan.

# %% [markdown]
# Selanjutnya, bandingkan performa model pada himpunan data pengujian:

# %%
test_loss, test_acc = model.evaluate(gambar_uji,  label_uji, verbose=2)

print('\nTingkat Akurasi Pengujian:', test_acc)
# Out:
# 313/313 - 0s - loss: 0.0805 - accuracy: 0.9778
#
# Tingkat Akurasi Pengujian: 0.9778000116348267

# %% [markdown]
# Ternyata keakuratan pada set data uji sedikit lebih rendah daripada keakuratan pada set data pelatihan. Kesenjangan antara akurasi pelatihan dan akurasi pengujian ini menunjukkan overfitting . Overfitting terjadi saat model machine learning berperforma lebih buruk pada input baru yang sebelumnya tidak terlihat daripada pada data pelatihan. Model overfitted "mengingat" noise dan detail dalam set data pelatihan ke titik yang berdampak negatif pada performa model pada data baru.

# %% [markdown]
# Dengan model yang telah dilatih, kita dapat menggunakannya untuk membuat prediksi tentang beberapa gambar. Nilai output ini akan diubah menjadi nilai probabilitas menggunakan fungsi `Softmax` sehingga lebih mudah diinterpretasikan.

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
prediksi = probability_model.predict(gambar_uji)

# %% [markdown]
# Di sini, model telah memprediksi label untuk setiap gambar di set pengujian. Mari kita lihat prediksi pertama:

# %%
prediksi[0]
# Out:
# array([8.8648893e-09, 7.8986914e-11, 2.0348472e-07, 3.9908923e-06,
#        6.3698130e-13, 4.0747195e-10, 1.0921050e-15, 9.9999511e-01,
#        3.1915413e-08, 6.9113554e-07], dtype=float32)

# %% [markdown]
# Prediksi adalah array angka dengan panjang 10. Mereka mewakili "kemungkinan" model bahwa gambar tersebut sesuai dengan masing-masing dari 10 kelas pakaian yang berbeda. Kita dapat melihat label mana yang memiliki nilai kemungkinan tertinggi:

# %%
np.argmax(prediksi[0])
# Out:
# 7

# %% [markdown]
# Jadi, model paling yakin bahwa gambar ini adalah **sepatu bot pergelangan kaki**, atau `nama_kelas[9]` . Pemeriksaan label uji menunjukkan bahwa klasifikasi ini benar:

# %%
label_uji[0]
# Out:
# 7

# %% [markdown]
# Mari kita menuliskan proses di atas dalam sebuah blok kode dengan sedikit perubahan berikut:

# %%
# Impor Library Tensor Flow
import tensorflow as tf

# Mengunduh dataset
mnist = tf.keras.datasets.mnist
# Membuka dataset dan menyimpanya menjadi data array latih dan uji
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# Melakukan penyiapan data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Membangun model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),                 # Layer Input      
  tf.keras.layers.Dense(512, activation=tf.nn.relu),             # Layer Hiden
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)            # Layer Output
])

# Kompilasi Model
model.compile(loss='sparse_categorical_crossentropy',            # Fungsi loss
              optimizer='adam',                                  # Fungi Optimasi
              metrics=['accuracy'])                              # Metrik Akurasi

# Melatih model
model.fit(x_train,                                               # Data Latih
          y_train,                                               # Label Latih
          epochs=10)                                             # Iterasi yang diinginkan

# Evaluasi model
test_loss, test_acc = model.evaluate(x_test,                     # Data Uji
                                     y_test,                     # Label Uji
                                     verbose=2)

print('\nTingkat Akurasi Pengujian:', test_acc)

# Contoh Prediksi
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
prediksi = probability_model.predict(x_test)
y_test[0]
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2013 - accuracy: 0.9403
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0815 - accuracy: 0.9754
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0533 - accuracy: 0.9831
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0372 - accuracy: 0.9880
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0276 - accuracy: 0.9913
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0208 - accuracy: 0.9931
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0174 - accuracy: 0.9942
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0136 - accuracy: 0.9955
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0122 - accuracy: 0.9958
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0114 - accuracy: 0.9965
# 313/313 - 1s - loss: 0.0805 - accuracy: 0.9811
#
# Tingkat Akurasi Pengujian: 0.9811000227928162
# 7

# %% [markdown]
# Pada proses sebelumnya, pelatihan model akan berhenti jika jumlah iterasi yang kita inginkan(epoch) selesai dilakukan. Bagaimana jika kita mengganti kriteria ini dengan nilai akurasi yang kita inginkan. Kita dapat melakukannya dengan membuat fungsi callback seperti di bawah ini.

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.99):
            print("\nModel telah mencapai akurasi 99%, proses Pelatihan dihentikan!")
            self.model.stop_training = True
callbacks = myCallback()

# %%
# Impor Library Tensor Flow
import tensorflow as tf

# Mengunduh dataset
mnist = tf.keras.datasets.mnist

# Membuka dataset dan menyimpanya menjadi data array latih dan uji
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# Melakukan penyiapan data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Membangun model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),                 # Layer Input      
  tf.keras.layers.Dense(512, activation=tf.nn.relu),             # Layer Hiden
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)            # Layer Output
])

# Kompilasi Model
model.compile(loss='sparse_categorical_crossentropy',            # Fungsi loss
              optimizer='adam',                                  # Fungi Optimasi
              metrics=['accuracy'])                              # Metrik Akurasi

# Melatih model
# Melatih model
model.fit(x_train,                                               # Data Latih
          y_train,                                               # Label Latih
          epochs=10,                                             # Iterasi yang diinginkan
          callbacks=[callbacks])                                 # Kriterian henti(Callback)

# Evaluasi model
test_loss, test_acc = model.evaluate(x_test,                     # Data Uji
                                     y_test,                     # Label Uji
                                     verbose=2)

print('\nTingkat Akurasi Pengujian:', test_acc)

# Contoh Prediksi
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
prediksi = probability_model.predict(x_test)
y_test[0]
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2009 - accuracy: 0.9407
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0816 - accuracy: 0.9746
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0516 - accuracy: 0.9837
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0379 - accuracy: 0.9878
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0261 - accuracy: 0.9917
#
# Model telah mencapai akurasi 99%, proses Pelatihan dihentikan!
# 313/313 - 1s - loss: 0.0735 - accuracy: 0.9790
#
# Tingkat Akurasi Pengujian: 0.9789999723434448
# 7

# %% [markdown]
# Dari hasil tersebut membuktikan bahwa pengujian dengan metode ini mendekati sempura dengan tingkat akurasi mencapai 10.
